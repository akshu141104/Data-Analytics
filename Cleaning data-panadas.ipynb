# %% [markdown]
# Data Cleaning
#
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
# Empty cell,Data in wrong format,Wrong data,Duplicates

# %% [markdown]
# Empty Cells
#
# Empty cells can potentially give you a wrong result when you analyze data.
#
#
#
#
#
# Remove Rows
#
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Admin\Downloads\netflix1.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r'C:\Users\Admin\Downloads\netflix1.csv')
#       4 print(df.head())
#
# ...

# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')
new_df = df.dropna()
#dropna() method returns a new DataFrame, and will not change the original.
print(new_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')
#       4 new_df = df.dropna()
#       5 #dropna() method returns a new DataFrame, and will not change the original.
#
# ...

# %% [markdown]
# dropna = remove rows with missing values from CSV data
# row completely delete have an even 1 missing value happend

# %% [markdown]
# If you want to change the original DataFrame, use the inplace = True argumen

# %%
# Remove all rows with NULL values:

import pandas as pd
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')
df.dropna(inplace = True)
print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[21], line 4
#       1 # Remove all rows with NULL values:
#       3 import pandas as pd
# ----> 4 df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')
#       5 df.dropna(inplace = True)
#       6 print(df.to_string())
#
# ...

# %% [markdown]
# Replace Empty Values
#
# Another way of dealing with empty cells is to insert a new value instead.
#
# This way you do not have to delete entire rows just because of some empty cells.
#
# The fillna() method allows us to replace empty cells with a value:

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')

df.fillna(130, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[22], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\\Users\\Admin\\Downloads\\netflix1.csv')
#       4 df.fillna(130, inplace = True)
#
# ...

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\sales_data.csv')
df.fillna({"Calories": 130}, inplace=True)

# %% [markdown]
# fillna() is used to replace missing values in dataset instead of removing them
